# %%
import tensorflow as tf
import os
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_ahttps://arxiv.org/pdf/1409.0473.pdf
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_out_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>', U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)
            if verbose:
                print('Ws+Uh>', Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
from attention import AttentionLayer

# %%
from nltk.corpus import stopwords

# %%
import tensorflow

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# #Import the Libraries

# %%
import numpy as np
import pandas as pd 
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"C:\Users\heman\Downloads\Reviews.csv\Reviews.csv")

# %% [markdown]
# # Drop Duplicates and NA values

# %%
data.drop_duplicates(subset=['Text'],inplace=True)#dropping duplicates
data.dropna(axis=0,inplace=True)#dropping na

# %% [markdown]
# # Information about dataset
#
# Let us look at datatypes and shape of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393565 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      393565 non-null  int64
#  1   ProductId               393565 non-null  object
#  2   UserId                  393565 non-null  object
#  3   ProfileName             393565 non-null  object
#  4   HelpfulnessNumerator    393565 non-null  int64
#  5   HelpfulnessDenominator  393565 non-null  int64
#  6   Score                   393565 non-null  int64
#  7   Time                    393565 non-null  int64
#  8   Summary                 393565 non-null  object
#  9   Text                    393565 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 33.0+ MB

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %%
stop_words = set(stopwords.words('english')) 

def text_cleaner(text,num):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# %%
#call the function
cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t,0))

# %%
cleaned_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
#call the function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(text_cleaner(t,1))

# %%
cleaned_summary[:10]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy',
#  'nice taffy',
#  'great just as good as the expensive brands',
#  'wonderful tasty taffy',
#  'yay barley',
#  'healthy dog food']

# %%
data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary

# %%
data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %%
cnt=0
for i in data['cleaned_summary']:
    if(len(i.split())<=8):
        cnt=cnt+1
print(cnt/len(data['cleaned_summary']))
# Out:
# 0.9458615476477837

# %%
max_text_len=30
max_summary_len=8

# %%
cleaned_text =np.array(data['cleaned_text'])
cleaned_summary=np.array(data['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
df=pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['summary']),test_size=0.1,random_state=0,shuffle=False)

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 67.95358341847906
# Total Coverage of rare words: 1.4332652451318657

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

# %%
x_voc
# Out:
# 17565

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 76.03715468283761
# Total Coverage of rare words: 2.5836037127799187

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

# %% [markdown]
# Let us check whether word count of start token is equal to length of the training data

# %%
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (192589, 192589)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K 
K.clear_session()

latent_dim = 300
embedding_dim=100

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 100)      1756500     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 30, 300), (N 481200      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 30, 300), (N 721200      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    498000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 30, 300), (N 721200      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 300),  481200      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 300),  180300      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 600)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 4980)   2992980     concat_layer[0][0]
# ==================================================================================================
# Total params: 7,832,580
# Trainable params: 7,832,580
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 1481/1481 [==============================] - 2281s 2s/step - loss: 2.7239 - val_loss: 2.4575
# Epoch 2/50
# 1481/1481 [==============================] - 2330s 2s/step - loss: 2.3918 - val_loss: 2.3077
# Epoch 3/50
# 1481/1481 [==============================] - 2324s 2s/step - loss: 2.2745 - val_loss: 2.2267
# Epoch 4/50
# 1481/1481 [==============================] - 2321s 2s/step - loss: 2.2048 - val_loss: 2.1740
# Epoch 5/50
# 1481/1481 [==============================] - 2321s 2s/step - loss: 2.1557 - val_loss: 2.1368
# Epoch 6/50
# 1481/1481 [==============================] - 2306s 2s/step - loss: 2.1226 - val_loss: 2.1201
# Epoch 7/50
# 1481/1481 [==============================] - 2317s 2s/step - loss: 2.0989 - val_loss: 2.1073
# Epoch 8/50
# 1481/1481 [==============================] - 2294s 2s/step - loss: 2.0790 - val_loss: 2.0938
# Epoch 9/50
# 1481/1481 [==============================] - 2293s 2s/step - loss: 2.0675 - val_loss: 2.0801
# Epoch 10/50
# 1481/1481 [==============================] - 2288s 2s/step - loss: 2.0524 - val_loss: 2.0742
# Epoch 11/50
# 1481/1481 [==============================] - 2298s 2s/step - loss: 2.0450 - val_loss: 2.0708
# Epoch 12/50
# 1481/1481 [==============================] - 2290s 2s/step - loss: 2.0324 - val_loss: 2.0642
# Epoch 13/50
# 1481/1481 [==============================] - 2305s 2s/step - loss: 2.0204 - val_loss: 2.0651
# Epoch 14/50
# 1481/1481 [==============================] - 2325s 2s/step - loss: 2.0109 - val_loss: 2.0561
# Epoch 15/50
# 1481/1481 [==============================] - 2319s 2s/step - loss: 2.0026 - val_loss: 2.0717
# Epoch 16/50
# 1481/1481 [==============================] - 2328s 2s/step - loss: 1.9925 - val_loss: 2.0592
# Epoch 00016: early stopping

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %% [markdown]
# Let us define the functions to convert an integer sequence to a word sequence for summary as well as the reviews:

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
import googletrans
from googletrans import Translator
translator = Translator()

# %% [markdown]
# Here are a few summaries generated by the model:

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    #print('Translated summary:',translator.translate(decode_sequence(x_tr[i].reshape(1,max_text_len)),dest='kn').text)
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Original summary: good quality dog food
# Predicted summary:  great dog food
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Original summary: not as advertised
# Predicted summary:  not what ordered
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Original summary: cough medicine
# Predicted summary:  not what expected
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Original summary: great taffy
# Predicted summary:  taffy
#
#
# Review: saltwater taffy great flavors soft chewy candy individually wrapped well none candies stuck together happen expensive version would highly recommend candy served beach themed party everyone loved
# Original summary: just as good as the expensive brands
# Predicted summary:  taffy
#
#
# Review: taffy good soft chewy flavors amazing would definitely recommend buying satisfying
# Original summary: wonderful tasty taffy
# Predicted summary:  taffy
#
#
# Review: right mostly sprouting cats eat grass love rotate around wheatgrass rye
# Original summary: yay barley
# Predicted summary:  cats love it
#
#
# Review: healthy dog food good digestion also good small puppies dog eats required amount every feeding
# Original summary: healthy dog food
# Predicted summary:  great dog food
#
#
# Review: good flavor came securely packed fresh delicious love twizzlers
# Original summary: fresh and greasy
# Predicted summary:  delicious
#
#
# Review: strawberry twizzlers guilty pleasure yummy six pounds around son
# Original summary: strawberry twizzlers yummy
# Predicted summary:  delicious
#
#
# Review: daughter loves twizzlers shipment six pounds really hit spot exactly would expect six packages strawberry twizzlers
# Original summary: lots of twizzlers just what you expect
# Predicted summary:  great candy
#
#
# Review: love eating good watching tv looking movies sweet like transfer zip lock baggie stay fresh take time eating
# Original summary: poor taste
# Predicted summary:  delicious
#
#
# Review: satisfied twizzler purchase shared others enjoyed definitely ordering
# Original summary: love it
# Predicted summary:  great product
#
#
# Review: candy delivered fast purchased reasonable price home bound unable get store perfect
# Original summary: home delivered
# Predicted summary:  great candy
#
#
# Review: husband twizzlers addict bought many times amazon government employees living overseas cannot get country always fresh tasty packed well arrive timely manner
# Original summary: always fresh
# Predicted summary:  fresh and fresh
#
#
# Review: bought husband currently overseas loves apparently staff likes also generous amounts twizzlers ounce bag well worth price twizzlers strawberry ounce bags
# Original summary: twizzlers
# Predicted summary:  great product
#
#
# Review: remember buying candy kid quality dropped years still superb product disappointed
# Original summary: delicious product
# Predicted summary:  candy
#
#
# Review: love candy weight watchers cut back still craving
# Original summary: twizzlers
# Predicted summary:  love these
#
#
# Review: lived us yrs miss twizzlers go back visit someone visits always stock say yum sell mexico faithful buyer often able buy right
# Original summary: please sell these in mexico
# Predicted summary:  love this stuff
#
#
# Review: product received advertised twizzlers strawberry ounce bags
# Original summary: twizzlers strawberry
# Predicted summary:  not what expected
#
#
# Review: candy red flavor plan chewy would never buy
# Original summary: nasty no flavor
# Predicted summary:  good candy
#
#
# Review: glad amazon carried batteries hard time finding elsewhere unique size need garage door opener great deal price
# Original summary: great bargain for the price
# Predicted summary:  great value
#
#
# Review: offer great price great taste thanks amazon selling product
# Original summary: this is my taste
# Predicted summary:  great product
#
#
# Review: us celiac disease product lifesaver could better getting almost half price grocery health food store love mccann instant oatmeal flavors thanks abby
# Original summary: love gluten free oatmeal
# Predicted summary:  great product
#
#
# Review: else need know oatmeal instant expensive kroger store brand oatmeal maybe little tastier better texture something still oatmeal mm convenient
# Original summary: it is oatmeal
# Predicted summary:  oatmeal
#
#
# Review: ordered wife reccomended daughter almost every morning likes flavors happy happy mccann instant irish oatmeal variety pack regular apples cinnamon maple brown sugar count boxes
# Original summary: wife favorite breakfast
# Predicted summary:  oatmeal
#
#
# Review: mccann oatmeal every morning ordering amazon able save almost per box great product tastes great healthy
# Original summary: food great
# Predicted summary:  great oatmeal
#
#
# Review: mccann oatmeal good quality choice favorite apples cinnamon find none overly sugary good hot breakfast minutes excellent
# Original summary: good hot breakfast
# Predicted summary:  delicious oatmeal
#
#
# Review: really like mccann steel cut oats find cook often tastes much better grocery store brands convenient anything keeps eating oatmeal regularly good thing
# Original summary: great taste and convenience
# Predicted summary:  great oats
#
#
# Review: seems little wholesome supermarket brands somewhat mushy quite much flavor either pass muster kids probably buy
# Original summary: hearty oatmeal
# Predicted summary:  not so good
#
#
# Review: good oatmeal like apple cinnamon best though would follow directions package since always comes soupy taste could since like oatmeal really thick add milk top
# Original summary: good
# Predicted summary:  oatmeal
#
#
# Review: flavors good however see oats brand mushy
# Original summary: mushy
# Predicted summary:  not what expected
#
#
# Review: stuff buy big box stores nothing healthy carbs sugars save money get something least taste
# Original summary: same stuff
# Predicted summary:  tastes like low carb
#
#
# Review: oatmeal good mushy soft like quaker oats way go
# Original summary: do not like it
# Predicted summary:  oatmeal
#
#
# Review: used spicy foods south texas spicy doubt much habanero used could take notch two
# Original summary: not ass kickin
# Predicted summary:  spicy spicy
#
#
# Review: roast large cast iron pan grill smell wonderful roasted beans taste delicious importantly coffee smooth bitter aftertaste numerous occasions send roasted beans home friends like much
# Original summary: our guests love it
# Predicted summary:  delicious
#
#
# Review: deal awesome arrived halloween indicated enough satisfy trick treaters love quality product much less expensive local store candy
# Original summary: awesome deal
# Predicted summary:  great deal
#
#
# Review: chocolate say great variety everything family loves family six goes fast perfect variety kit kat reeses take five
# Original summary: how can you go wrong
# Predicted summary:  great chocolate
#
#
# Review: great product nice combination chocolates perfect size bags plenty shipped promptly kids neighborhood liked candies
# Original summary: awsome kids in loved us
# Predicted summary:  great product
#
#
# Review: halloween sent bag daughters class share chocolate fresh enjoyed many
# Original summary: great deal
# Predicted summary:  great chocolate
#
#
# Review: watch prices assortment good get gold box purchase price less target
# Original summary: better price for this at target
# Predicted summary:  overpriced
#
#
# Review: bag candy online pretty expensive cheaper order compete grocery stores good combination favorite candy
# Original summary: pretty expensive
# Predicted summary:  good candy
#
#
# Review: arrived days stale could eat bags
# Original summary: stale product
# Predicted summary:  stale
#
#
# Review: product serves well source electrolytes long run bike ride tried flavors really like grapefruit flavor taste actually like slight carbonation use hammer products really like whole product line
# Original summary: great source of
# Predicted summary:  great product
#
#
# Review: stuff really works preventing cramping middle latter stages rides pop water bottle set flavor fine goes easy
# Original summary: great for cramps
# Predicted summary:  works great
#
#
# Review: sooooo deliscious bad ate em fast gained fault
# Original summary: pretzel
# Predicted summary:  yummy
#
#
# Review: okay would go way buy
# Original summary: nothing special
# Predicted summary:  not what expected
#
#
# Review: tea flavor whole brunch flavors returnable wasted bucks
# Original summary: no tea flavor
# Predicted summary:  not what expected
#
#
# Review: taste great berries melted may order winter order cold weather enjoy flavor
# Original summary: order only in cold weather
# Predicted summary:  great product
#
#
# Review: know cannot make tea good granted south know never enjoyed tea sweet without sweet tastes crisp
# Original summary: this is the best
# Predicted summary:  delicious
#
#
# Review: peppermint stick delicious fun eat dad got one christmas remembered similar one little girl love
# Original summary: delicious
# Predicted summary:  delicious
#
#
# Review: great gift ages purchased giant canes recipients loved much kept would eat
# Original summary: great
# Predicted summary:  great gift
#
#
# Review: three dogs love food bought specifically one dogs food allergies works great hot spots tummy problems love ships right door free shipping
# Original summary: great food
# Predicted summary:  dogs love it
#
#
# Review: shepherd collie mix ibs vet recommended limited ingredient food really helped symptoms likes always buy amazon cheaper free shipping
# Original summary: great for stomach problems
# Predicted summary:  great dog food
#
#
# Review: great food love idea one food ages breeds real convenience well really good product dogs eat less almost gas poop regular perfect consistency else mom ask
# Original summary: great food
# Predicted summary:  great food
#
#
# Review: great dog food dog allergies brand one feed
# Original summary: great dog food
# Predicted summary:  great dog food
#
#
# Review: food great ages dogs year old puppy soft hardly ever get sick food good especially amazon prime shipping
# Original summary: mm mm good
# Predicted summary:  puppy food
#
#
# Review: food get pet store delivered door price slightly less
# Original summary: so convenient
# Predicted summary:  great food
#
#
# Review: pup experienced allergies forms itching dog foods cheap buy anywhere food crazy preservatives cause health problems pets food works wonders reducing allergies dog loves food message approved
# Original summary: allergy sensitive dog food dogs love it
# Predicted summary:  great dog food
#
#
# Review: fed golden retriever hated would eat gave terrible diarrhea buying also super expensive
# Original summary: bad
# Predicted summary:  yuck
#
#
# Review: mouth says love thee let count ways like apple products must item draw back shipping cost heavy
# Original summary: taste wise it is star item
# Predicted summary:  great product but too expensive
#
#
# Review: arrived slightly thawed parents would accept however company helpful issued full refund
# Original summary: great support
# Predicted summary:  not what ordered
#
#
# Review: crust tarts perfect husband loves crazy sour tart taste eat crust hubby takes filling kids think great maybe
# Original summary: tart
# Predicted summary:  great for pizza
#
#
# Review: absolutely scrumptuous husband love however another customer put expensive ship cost shipping
# Original summary: omaha apple
# Predicted summary:  great product but overpriced
#
#
# Review: nice alternative apple pie love fact slicing dicing easy prepare also loved fact make fresh whenever needed
# Original summary: loved these
# Predicted summary:  tasty and filling
#
#
# Review: like creme brulee loved easy sprinkle sugar came broil look amazing taste great guess thought really went way really took minutes ordering
# Original summary: the best
# Predicted summary:  delicious
#
#
# Review: expecting terms company reputation excellent home delivery products
# Original summary: disappointing
# Predicted summary:  excellent product
#
#
# Review: love asparagus recently never pickled asparagus oh goodness friend introduced exact brand could believe great stuff tasted loved much bought six pack got jars left gonna need
# Original summary: bliss
# Predicted summary:  love this stuff
#
#
# Review: diappointed flavor texture mix usually like low carb things tried diappointed specific one
# Original summary: low carb angel food puffs
# Predicted summary:  not bad
#
#
# Review: drinking tea long time used purchase doctor office available elsewhere glad buy amazon com drink tea throughout day like folks drink coffee wonderful taste
# Original summary: delicious tea
# Predicted summary:  great tea
#
#
# Review: one best teas ever tasted clean bright fresh great delivery quality try
# Original summary: the best tea ever bright clean
# Predicted summary:  great tea
#
#
# Review: love love green tea hard find area places internet charge big price usually get many boxes merchant definitely order seller thanks depend green tea fix everyday
# Original summary: tea review
# Predicted summary:  green tea
#
#
# Review: love tea helps curb eating day mom given friends try
# Original summary: wonderful tea
# Predicted summary:  great tea
#
#
# Review: italian lived italy years used buy cookies everyday breakfast italian espresso could find anywhere bay area great
# Original summary: great cookies
# Predicted summary:  great cookies
#
#
# Review: one cats allergic fish beef formula one eat much better ingredients prescription diets available vet kitties active soft shiny fur neither fat dry food reduces tartar buildup teeth also
# Original summary: wonderful food perfect for allergic kitties
# Predicted summary:  my cats love it
#
#
# Review: cats thrive extremely well dry cat food definitely much less hair ball throw ups fur great fit weight vendor ships extremely fast one top amazon suppliers book
# Original summary: holistic select cat food
# Predicted summary:  cats love it
#
#
# Review: fan hot spicy maruchan ramen long time enjoy spice love ramen love product bad way expensive amazon per walmart
# Original summary: great love hot spicy bad price here
# Predicted summary:  spicy ramen
#
#
# Review: eating ramen noodles since little kid never found better flavor hot spicy chicken hot like sure good
# Original summary: my favorite ramen
# Predicted summary:  spicy
#
#
# Review: love spicy ramen whatever reasons thing burns stomach badly burning sensation go away like hours sure healthy buy walmart way cheaper amazon
# Original summary: it burns
# Predicted summary:  my favorite
#
#
# Review: always fan ramen quick easy meal finding amazon decent price delivered door case amazing situation anyone find
# Original summary: amazing to the last bite
# Predicted summary:  best instant ramen
#
#
# Review: must bit soup tastes imagine fire might taste typically like spicy food good flavor find case soup flavor killed burn
# Original summary: not for me
# Predicted summary:  not so good
#
#
# Review: really loved spicy flavor found liking broth noodles usually opposite used heat might bother like hot hot foods might enough
# Original summary: great spicy flavor
# Predicted summary:  spicy spicy
#
#
# Review: bought allot different flavors happens one favorites getting soon
# Original summary: great flavor
# Predicted summary:  delicious
#
#
# Review: love flavor ramen eat flavors anymore taste bland comparison convenience delivered home price amazon bad still cheaper run pick case grocery store
# Original summary: tastes great but is cheaper locally
# Predicted summary:  great flavor but not great
#
#
# Review: best investment ever made ginger unbelievable fibrous like real ginger spicy kick perfect sugar calms worth lbs getting soon use topper ginger cupcakes cookies
# Original summary: tastes awesome looks beautiful
# Predicted summary:  best ginger ever
#
#
# Review: delicious cannot get australian ginger live compares favorably australian ginger purchased cities enjoy without traveling
# Original summary: happy face
# Predicted summary:  ginger chews
#
#
# Review: keep trying brands cheaper brands stupid ginger soooo worth money tender moist never let
# Original summary: simply the best
# Predicted summary:  best ginger ginger
#
#
# Review: bought office give people something sweet snack bite size easier people grab couple pieces rather entire licorice stick complaint one bags broke open shipping
# Original summary: nice snack
# Predicted summary:  good snack
#
#
# Review: twizzlers brand licorice much better well known brand get package free good deal black cherry good taste strawberry taste delicate barely
# Original summary: good licorice
# Predicted summary:  good licorice
#
#
# Review: love tasty infact think addicted buying packs bags reasonable going target getting bag savings bag use subscribe save several product love subscribe save
# Original summary: love these
# Predicted summary:  love these
#
#
# Review: one best salsas found long time stay away variety pack two come worth money
# Original summary: love the salsa
# Predicted summary:  salsa
#
#
# Review: remind dog treats made using pumpkin cinnamon kind bland favorite back nature product really loves three stars come
# Original summary: ehhh
# Predicted summary:  not my favorite
#
#
# Review: best cornmeal made regular cornbread hot water cornbread meal outstanding also fried oysters meal gave great texture flovor
# Original summary: awesome cornmeal
# Predicted summary:  best cornbread mix ever
#
#
# Review: fabulous marinade love use chicken either baked oven grill enough flavor flair even used dinner parties receive rave reviews guests definitely worth price super cheap super easy love
# Original summary: great marinade
# Predicted summary:  great marinade
#
#
# Review: works chicken fish beef pork fast easy makes taste excellent plus buying bulk box stores
# Original summary: awesome stuff
# Predicted summary:  great seasoning
#
#
# Review: got brother jorge cruise diet decided try one actually tastes pretty good
# Original summary: tastes good
# Predicted summary:  good taste
#
#
# Review: singles sell store box singles sure amazon selling box singles hazelnut coffee creamer favorite truly good buy
# Original summary: rip off price
# Predicted summary:  overpriced
#
#
# Review: awesome yummy flavor got healthy alternative desserts normally eat glad many things jello desserts still taste good good purchasing product flavor wonderful
# Original summary: jell
# Predicted summary:  delicious
#
#
# Review: deal healthiest salt use box last family year problem iodized sea salt raise blood pressure regular salt
# Original summary: great deal
# Predicted summary:  great salt
#
#
# Review: perfect size sea salt table picnic basket love shakes well clumping flows freely
# Original summary: great tasting sea salt with
# Predicted summary:  great salt

# %%
for i in range(0,100):
    print("Review:",seq2text(x_val[i]))
    print("Original summary:",seq2summary(y_val[i]))
    a = decode_sequence(x_val[i].reshape(1,max_text_len))
    print("Predicted summary:",a)
    print('Translated summary:',translator.translate(a,dest='kn').text)
    print("\n")
# Out:
# Review: good value natural peanut butter especially since stir skippy little added sugar much compared smucker natural peanut butter
# Original summary: good value
# Predicted summary:  good stuff
# Translated summary: ಒಳ್ಳೆಯ ವಿಷಯ
#
#
# Review: peanut butter natural tastes great eat ritz crackers mainly creamy says jar good today talking haha great delivery time
# Original summary: de licious and nutritious
# Predicted summary:  great tasting peanut butter
# Translated summary: ಉತ್ತಮ ರುಚಿ ಕಡಲೆಕಾಯಿ ಬೆಣ್ಣೆ
#
#
# Review: ever good pure natural peanut butter may natural regular blend still commercial peanut butter added oils ok would get
# Original summary: nothing
# Predicted summary:  not so good
# Translated summary: ಅಷ್ಟೊಂದು ಚೆನ್ನಾಗಿಲ್ಲ
#
#
# Review: delicious peanut butter easy spread cracker without breaking cracker negative occasionally air space jar really get full jar found jars love peanut butter
# Original summary: skippy peanut butter natural creamy
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: well shame saw natural label assumed ground peanuts wound jars regular old american peanut butter loaded sugar course tastes good mixed well stays mixed lasts long shelf pay things
# Original summary: always tastes good not what call natural
# Predicted summary:  not what expected
# Translated summary: ನಿರೀಕ್ಷಿಸಿದಂತೆ ಅಲ್ಲ
#
#
# Review: product delivered fast fact think got next day
# Original summary: awesome
# Predicted summary:  great product
# Translated summary: ಉತ್ತಮ ಉತ್ಪನ್ನ
#
#
# Review: check ingredients peanuts sugar palm oil salt go costco brand laura ingredients peanuts
# Original summary: all natural sugar palm oil salt added
# Predicted summary:  not what expected
# Translated summary: ನಿರೀಕ್ಷಿಸಿದಂತೆ ಅಲ್ಲ
#
#
# Review: warning natural peanut butter added sugar horrible anybody following sensible diet
# Original summary: deceptive use of natural
# Predicted summary:  yuck
# Translated summary: ಯಾಕ್
#
#
# Review: espresso fans must try blend smooth fabulous taste price nice cafe kimbo espresso forever
# Original summary: morning bliss
# Predicted summary:  great espresso
# Translated summary: ದೊಡ್ಡ ಎಸ್ಪ್ರೆಸೊ
#
#
# Review: rich flavor easy pallet tried espresso one decent bland rich low acid bold taste
# Original summary: good cup of coffee
# Predicted summary:  good espresso
# Translated summary: ಉತ್ತಮ ಎಸ್ಪ್ರೆಸೊ
#
#
# Review: short review coffee live napoli drink enough said simply best
# Original summary: the king of espresso
# Predicted summary:  best coffee ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಕಾಫಿ
#
#
# Review: truly delicious coffee side benefit making whole house smell like baking
# Original summary: of the best coffees have ever tasted
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: coffee hint chocolate delightful drink signed month subscription plan purchasing frequently someone really tastes coffee say truly enjoying
# Original summary: chocolate delight
# Predicted summary:  delicious coffee
# Translated summary: ರುಚಿಯಾದ ಕಾಫಿ
#
#
# Review: one best flavored coffees ever smell incredible taste wonderful big bag price great highly recommend trying regret
# Original summary: amazing
# Predicted summary:  best coffee ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಕಾಫಿ
#
#
# Review: artificial tasting cannot particularly taste chocolate caramel definitely coffee taste sure tastes like good also little sour
# Original summary: did not like it
# Predicted summary:  tastes like coffee
# Translated summary: ಕಾಫಿಯಂತೆ ರುಚಿ
#
#
# Review: love coffee lot flavor like flavored coffee good gets beans fresh every time get price great use buy coffee costco cheap tastes whole lot better
# Original summary: great coffee
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: usually like caramel candy sweet try flavor love flavors caramel brownies beautifully blended coffee flavor bit sweet recently ordered flavor continue cameron coffees smooth creamy
# Original summary: brownies in coffee cup
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: cameron chocolate caramel brownie coffee far tastiest coffee best breakfast front cozy fire flavor delicious
# Original summary: best tasting coffee
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: better could imagined close eyes feel like ate brownie covered caramel
# Original summary: yummy
# Predicted summary:  good stuff
# Translated summary: ಒಳ್ಳೆಯ ವಿಷಯ
#
#
# Review: tried cameron coffee par others dont enough lust flavor turns quite light even french press
# Original summary: and light
# Predicted summary:  not bad
# Translated summary: ಕೆಟ್ಟದ್ದಲ್ಲ
#
#
# Review: really looking forward coffee disappointed reorder received cameron toasted southern pecan coffee gift christmas totally delighted already reordered
# Original summary: cameron chocolate caramel brownie whole bean coffee
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: coffee bad tasting well cant really tell drinking smells delicious gotta admit taste awful stay away product worst coffee ever
# Original summary: this is an to coffee
# Predicted summary:  yuck
# Translated summary: ಯಾಕ್
#
#
# Review: drinking brand tea years whenever could find quality never reviewers say tea overpowering delicate aroma fruity taste tea tannic heats well
# Original summary: terrific tea
# Predicted summary:  best tea ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಚಹಾ
#
#
# Review: new black tea pleased discover others say aroma leaves calming pleasant taste brew based time seeping bitter cup yet extremely pleased tea recommend anyone
# Original summary: wonderful aroma and taste
# Predicted summary:  great tea
# Translated summary: ದೊಡ್ಡ ಚಹಾ
#
#
# Review: love black tea use flavored tea getting good stuff black tea make tast better flavored loose teas
# Original summary: great tea
# Predicted summary:  great tea
# Translated summary: ದೊಡ್ಡ ಚಹಾ
#
#
# Review: smoothest black tea come across delicious great aroma faint overpower tea great stuff glad able find online
# Original summary: smooth smooth smooth
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: read reviews tea right nice tea fresh people put together packaged antioxidants flavors lost outer packaging inner packaging
# Original summary: nice tea
# Predicted summary:  great tea
# Translated summary: ದೊಡ್ಡ ಚಹಾ
#
#
# Review: price expect sell kidding got joke
# Original summary: are you serious
# Predicted summary:  rip off
# Translated summary: ಕಿತ್ತುಹಾಕು
#
#
# Review: something high demand way consumer bottle water ridiculous people need get grip
# Original summary: ridiculous
# Predicted summary:  overpriced
# Translated summary: ಅಧಿಕ ಬೆಲೆಯ
#
#
# Review: one favorite coffees like flavor smooth rough edges many commercial blends
# Original summary: great coffee
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: received order coffee ordered community coffee alot times reason particular order packages sealed bottom coffee spilled outer package disappointed since paid packages use
# Original summary: package
# Predicted summary:  not what ordered
# Translated summary: ಆದೇಶಿಸಿದ್ದಲ್ಲ
#
#
# Review: large sweet soft hope get sold ready buy
# Original summary: really good turkish figs
# Predicted summary:  sweet
# Translated summary: ಸಿಹಿ
#
#
# Review: package recieved among best dried figs ever eaten definately buy
# Original summary: great figs
# Predicted summary:  best figs ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಅಂಜೂರದ ಹಣ್ಣುಗಳು
#
#
# Review: good quality described add unique baked recipes like whole seeds rather grounded version better fresh flavour
# Original summary: good quality as described
# Predicted summary:  good quality
# Translated summary: ಉತ್ತಮ ಗುಣಮಟ್ಟದ
#
#
# Review: hard time finding product stores happen go amazon see might daughter loves little candy eggs turn oatmeal fun eat good
# Original summary: fun to eat
# Predicted summary:  great product
# Translated summary: ಉತ್ತಮ ಉತ್ಪನ್ನ
#
#
# Review: love cereal cannot find local stores told stock maybe start showing great way get eat oatmeal
# Original summary: eggs
# Predicted summary:  great cereal
# Translated summary: ದೊಡ್ಡ ಧಾನ್ಯ
#
#
# Review: use cereal work children menu hard find retail finding amazon com nice surprise
# Original summary: great website for hard to find product
# Predicted summary:  great cereal
# Translated summary: ದೊಡ್ಡ ಧಾನ್ಯ
#
#
# Review: firm favorite breakfast time house many years pick low price pack seems taste even better
# Original summary: quaker instant oatmeal dinosaur eggs
# Predicted summary:  great breakfast
# Translated summary: ಉತ್ತಮ ಉಪಹಾರ
#
#
# Review: children really enjoy dinosaur oatmeal able find local store bought several boxes vacation florida got home searched amazon wed site found ordering future pleased product sevice received thanks
# Original summary: dinosaur oatmeal
# Predicted summary:  oatmeal
# Translated summary: ಓಟ್ಮೀಲ್
#
#
# Review: remember eating seven loved excited able eat
# Original summary: childhood memories
# Predicted summary:  great snack
# Translated summary: ದೊಡ್ಡ ತಿಂಡಿ
#
#
# Review: grandmother use make little love much searching years oatmeal adore favorite thing childhood
# Original summary: finally found it
# Predicted summary:  best oatmeal ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಓಟ್ ಮೀಲ್
#
#
# Review: daughter loves oatmeal excited find amazon unfortunately package came today four boxes opened oatmeal spilled box never shipping problem amazon disappointed
# Original summary: product was open when arrived
# Predicted summary:  oatmeal
# Translated summary: ಓಟ್ಮೀಲ್
#
#
# Review: ordered last christmas wrap give parents gift box received fresh good condition marzipan delicious enough whole family share think little gems become regular addition holiday celebration
# Original summary: great product
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: product great deal price ideal split use gifts marzipan lovers life candy decorated pieces fruit fresh would definitely purchase product bulk marzipan lbs pcs
# Original summary: bulk marzipan
# Predicted summary:  great product
# Translated summary: ಉತ್ತಮ ಉತ್ಪನ್ನ
#
#
# Review: candy wonderful ordering soon would encourage least ever marzipan great time try past jump enjoy
# Original summary: sinfully good
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: mother loves marzipan try get every christmas couple stores locally always priced quality good ordered online previously great quality marzipan really high quality great price fast shipping boot highly recommended
# Original summary: excellent seller
# Predicted summary:  great product
# Translated summary: ಉತ್ತಮ ಉತ್ಪನ್ನ
#
#
# Review: chokecherry tea simply tasty think pretty much says tasty
# Original summary: great flavor great tea
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: initially nervous purchase cans low price however beans good quality would buy roland complaint canned goods amazons usually arrive rather dented wish would packaging
# Original summary: lots of beans for low price
# Predicted summary:  good beans
# Translated summary: ಉತ್ತಮ ಬೀನ್ಸ್
#
#
# Review: wonderful product coffee well aroma enticing satisfying challenge encountered obtaining reasonable price often offered premium vis vis comparable items hopefully change supply meets must rising demand
# Original summary: wonderful product
# Predicted summary:  excellent product
# Translated summary: ಅತ್ಯುತ್ತಮ ಉತ್ಪನ್ನ
#
#
# Review: cannot drive time getting groceries amazon convenient amazon amazing things cannot get amazon nd time ordered soup addicted amazon best product
# Original summary: love this soup
# Predicted summary:  best soup ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಸೂಪ್
#
#
# Review: surprise smooth light coffee flavor good cup later night want cup coffee without staying late
# Original summary: good mild coffee
# Predicted summary:  good coffee
# Translated summary: ಉತ್ತಮ ಕಾಫಿ
#
#
# Review: coffee actually nice price way high bought box pack means packs would deal
# Original summary: too high price
# Predicted summary:  good coffee but not great
# Translated summary: ಉತ್ತಮ ಕಾಫಿ ಆದರೆ ಉತ್ತಮವಾಗಿಲ್ಲ
#
#
# Review: get boxes local grocery store know expensive
# Original summary: millstone cups
# Predicted summary:  overpriced
# Translated summary: ಅಧಿಕ ಬೆಲೆಯ
#
#
# Review: blend tried hubby love second favorite cappacino would recommend
# Original summary: fantastic taste
# Predicted summary:  great taste
# Translated summary: ದೊಡ್ಡ ರುಚಿ
#
#
# Review: like coffee bitter also like tasteless either tried many different brands coffee keurig favorite bitter nice smooth coffee flavor around good cup coffee
# Original summary: my favorite
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: price price wal mart get cheaper wal mart count found hard way ordered afghanistan wife states thinking would nice stash cups around house everything amazon cheaper
# Original summary: not worth it
# Predicted summary:  overpriced
# Translated summary: ಅಧಿಕ ಬೆಲೆಯ
#
#
# Review: morning coffee drinker usually drink strong stuff needed get may day started strong weak
# Original summary: enjoying the coffee
# Predicted summary:  strong coffee
# Translated summary: ಬಲವಾದ ಕಾಫಿ
#
#
# Review: love coffee keurig throughout day perfect taste family really hits spot ordered well hundred cups blend hope continue many years come
# Original summary: favorite coffee
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: delicious light roast blend coffee opinion closest get cup dunkin donuts coffee consumed well cups flavor cup consistently additionally price item better would find retail store live
# Original summary: my favorite cup
# Predicted summary:  delicious coffee
# Translated summary: ರುಚಿಯಾದ ಕಾಫಿ
#
#
# Review: coffee greatest full flavored yet bitter smooth full right flavor great cup coffee
# Original summary: best coffee ever
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: coffee smoothest one tried gentle stomach tastes good certainly buy
# Original summary: millstone breakfast blend
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: love millstone coffee thrilled find kcups favorite blend special often
# Original summary: coffee in kcup or any other way
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: glad found product amazon com coffee delicious price get tired paying cup expensive brands thank amazon keep good work
# Original summary: millstone coffee
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: smooth coffee upset stomach coffees become millstone breakfast blend life fan best coffee ever keurig
# Original summary: excellent product
# Predicted summary:  best coffee ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಕಾಫಿ
#
#
# Review: one favorites use keurig since fan bold bitter coffees love millstone smooth balanced lots body thought price good live atlanta cannot seem find box
# Original summary: one of the better cups
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
#
#
# Review: info mean boxes total mean get total free shipping
# Original summary: unclear amount of product being sent
# Predicted summary:  rip off
# Translated summary: ಕಿತ್ತುಹಾಕು
#
#
# Review: ordered february th yet receive despite stock status dont see link contact regard order thought would write review see summer
# Original summary: two months for it to ship wtf
# Predicted summary:  never received
# Translated summary: ಎಂದಿಗೂ ಸ್ವೀಕರಿಸಲಿಲ್ಲ
#
#
# Review: whole family loves flavor husband adds tea available stores better everything else
# Original summary: raspberry sparkling ice
# Predicted summary:  great tea
# Translated summary: ದೊಡ್ಡ ಚಹಾ
#
#
# Review: ok tried alot calorie drinks one best hard believe calories carbs even though got free shipping found cheaper walmart love product
# Original summary: hard to believe it has calories
# Predicted summary:  good stuff
# Translated summary: ಒಳ್ಳೆಯ ವಿಷಯ
#
#
# Review: sparkling ice red raspberry like crack cannot get enough cheaper buy product amazon rather grocery store amazon rocks
# Original summary: sparkling ice red raspberry
# Predicted summary:  best soda ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಸೋಡಾ
#
#
# Review: love drink many reasons one aspartame calories tastes great
# Original summary: yummy drinks
# Predicted summary:  great product
# Translated summary: ಉತ್ತಮ ಉತ್ಪನ್ನ
#
#
# Review: refreshing tasting beverage unlike anything tasted juice carbonation mix great together
# Original summary: fantastic beverage
# Predicted summary:  great tasting
# Translated summary: ಮಹಾನ್ ರುಚಿ
#
#
# Review: get even hands ridiculous reason use coloring harmful clothes floors rugs
# Original summary: stains worse blood
# Predicted summary:  overpriced
# Translated summary: ಅಧಿಕ ಬೆಲೆಯ
#
#
# Review: glad appeared market fantastic taste overly sweet enough sweet attack glad added tops great taste glad amazon product
# Original summary: great
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: really liek raspberry flavor really great hot day quenches thirst refreshing taste like enjoy
# Original summary: sparkling ice
# Predicted summary:  great taste
# Translated summary: ದೊಡ್ಡ ರುಚಿ
#
#
# Review: refreshing lingering taste healthy like sparkling sensation better served cold
# Original summary: ice review
# Predicted summary:  great tasting drink
# Translated summary: ಉತ್ತಮ ರುಚಿಯ ಪಾನೀಯ
#
#
# Review: tasty totally delicious subscription flavor ice beverages easy convenient delivered door put directly refrigerator best buy subscription plan less expensive store even sale flavor delicious favorite flavors equally good
# Original summary: delicious sparkling ice black raspberry
# Predicted summary:  delicious
# Translated summary: ರುಚಿಕರವಾದ
#
#
# Review: physician patient diabetes first recommended product least flavors enjoyed especially black raspberry pomegranate berry harvest peach much flavor calories great product
# Original summary: sparkling ice
# Predicted summary:  great flavor
# Translated summary: ದೊಡ್ಡ ಸುವಾಸನೆ
#
#
# Review: favorite flavor tried others one best healthy caffeine sodium sugar etc feel like drinking soda order case amazon least expensive arrives right door carry car
# Original summary: healthy good tasting drink
# Predicted summary:  love this stuff
# Translated summary: ಈ ವಿಷಯವನ್ನು ಪ್ರೀತಿಸಿ
#
#
# Review: favorite zero calorie drink sparkling ice flavors one best taste weird love fizz best aspartame
# Original summary: black rasberry is the best
# Predicted summary:  best soda ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಸೋಡಾ
#
#
# Review: love stuff recently tried flavor far best tried tastes like soda like water kids love lemonade grapefruit orange mango also good one amazing one cared coconut pineapple
# Original summary: the best flavor
# Predicted summary:  best soda ever
# Translated summary: ಅತ್ಯುತ್ತಮ ಸೋಡಾ
#
#
# Review: knew zero calories good overall impressed always right price
# Original summary: delicious
# Predicted summary:  good stuff
# Translated summary: ಒಳ್ಳೆಯ ವಿಷಯ
#
#
# Review: stuff may habit forming absolutely love love love flavor sure hope stock without one months know flavor makes crave way awesome warned
# Original summary: warning addicting
# Predicted summary:  love this stuff
# Translated summary: ಈ ವಿಷಯವನ್ನು ಪ್ರೀತಿಸಿ
#
#
# Review: product new favorite drink buy much heavy carry thought would easier get way flavor sweet sparkly aftertaste great
# Original summary: best drink ever
# Predicted summary:  great taste
# Translated summary: ದೊಡ್ಡ ರುಚಿ
#
#
# Review: love stuff nice alternative soda plain water bonus calories tried flavor like
# Original summary: sparkling ice
# Predicted summary:  great soda
# Translated summary: ದೊಡ್ಡ ಸೋಡಾ
#
#
# Review: really enjoy drinking help get past craving soda great flavor
# Original summary: yummy
# Predicted summary:  great taste
# Translated summary: ದೊಡ್ಡ ರುಚಿ
#
#
# Review: really like black raspberry alot personally like mix fruit juice favorite ice though lemon lime going take boat summer think probably make pretty good margarita always
# Original summary: flavor but lemon lime is our favorite
# Predicted summary:  good flavor
# Translated summary: ಉತ್ತಮ ಸುವಾಸನೆ
#
#
# Review: oh gosh stuff good open slowly carefully top bottle red colored black raspberry
# Original summary: fizzy bubbly
# Predicted summary:  not what expected
# Translated summary: ನಿರೀಕ್ಷಿಸಿದಂತೆ ಅಲ್ಲ
#
#
# Review: like product could find stores anymore glad enjoy much
# Original summary: black raspberry
# Predicted summary:  great product
# Translated summary: ಉತ್ತಮ ಉತ್ಪನ್ನ
#
#
# Review: best tasting sparkling ice waters also takes care soda desires stopped drinking much soda lose weight helps also like idea calories
# Original summary: great tasting
# Predicted summary:  great soda
# Translated summary: ದೊಡ್ಡ ಸೋಡಾ
#
#
# Review: sparkling ice awesome thanks amazon want available everywhere ice sparkling ice black raspberry ounce bottles
# Original summary: sparkling ice
# Predicted summary:  great product
# Translated summary: ಉತ್ತಮ ಉತ್ಪನ್ನ
#
#
# Review: tried product whim tastes great calories includes vitamins anti oxidents get much better
# Original summary: awesome
# Predicted summary:  great taste
# Translated summary: ದೊಡ್ಡ ರುಚಿ
#
#
# Review: received black raspberry sparkling flavored water today love right amount sweetness tastes good tried many flavored waters one favorites like taste black raspberry disappointed
# Original summary: love this water
# Predicted summary:  refreshing
# Translated summary: ರಿಫ್ರೆಶ್
#
#
# Review: love orange mango lemon lime flavors refreshing flavor tastes like bad lollipop recommend anyone else unless like taste candy drinks
# Original summary: lollipop taste
# Predicted summary:  tastes like orange
# Translated summary: ಕಿತ್ತಳೆಯಂತೆ ರುಚಿ
#
#
# Review: flavor little sweet prefer something bit tart side biggest complaint matter bottle little move stuff comes squirting bottle open beware
# Original summary: watch out when you open it
# Predicted summary:  sweet but not too sweet
# Translated summary: ಸಿಹಿ ಆದರೆ ತುಂಬಾ ಸಿಹಿ ಅಲ್ಲ
#
#
# Review: taste good water brand flavors stain incredibly badly spilled three shirts work single pack bought costco flavored water ever tried incredibly annoying feature
# Original summary: stains like no other flavored water
# Predicted summary:  water
# Translated summary: ನೀರು
#
#
# Review: chocolate bars taste great also received perfect condition way west africa
# Original summary: delicious
# Predicted summary:  great chocolate
# Translated summary: ದೊಡ್ಡ ಚಾಕೊಲೇಟ್
#
#
# Review: walkers crisps good bacon particular favorite greasy like american name brand chips bacon flavor great highly recommend
# Original summary: bacon crisps are so goooood
# Predicted summary:  great flavor
# Translated summary: ದೊಡ್ಡ ಸುವಾಸನೆ
#
#
# Review: say real stuff dark full flavored strong like coffee
# Original summary: the real stuff
# Predicted summary:  good coffee
# Translated summary: ಉತ್ತಮ ಕಾಫಿ
#
#
# Review: love rich brew starbucks cannot beat amazon prices much economical relying chain grocery store neighborhood
# Original summary: best starbucks coffee
# Predicted summary:  great coffee
# Translated summary: ದೊಡ್ಡ ಕಾಫಿ
